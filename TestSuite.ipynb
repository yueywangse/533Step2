# %%
import unittest
from canvasacademicinsights.tests.test_canvasinsights import TestMain

def my_suite():
    suite = unittest.TestSuite()
    result = unittest.TestResult()
    suite.addTest(TestMain('test_clean_data'))
    suite.addTest(TestMain('test_get_courses'))
    runner = unittest.TextTestRunner()
    print(runner.run(suite))
                      
my_suite()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       9     runner = unittest.TextTestRunner()
#      10     print(runner.run(suite))
# ---> 12 my_suite()
#
# Cell In[1], line 7, in my_suite()
#       5 suite = unittest.TestSuite()
#       6 result = unittest.TestResult()
# ----> 7 suite.addTest(TestMain('test_clean_data'))
#       8 suite.addTest(TestMain('test_get_courses'))
#       9 runner = unittest.TextTestRunner()
#
# NameError: name 'TestMain' is not defined
