# %%
import unittest
from canvasacademicinsights.tests.test_canvasinsights import TestMain
from canvasacademicinsights.tests.test_canvasdataretriever import TestCleaner

def my_suite():
    suite = unittest.TestSuite()
    result = unittest.TestResult()
    suite.addTest(TestMain('test_clean_data'))
    suite.addTest(TestMain('test_get_courses'))
    suite.addTest(TestCleaner('test_clean_data'))
    suite.addTest(TestCleaner('test_grade'))
    suite.addTest(TestCleaner('test_assignment_grade'))
    suite.addTest(TestCleaner('test_quiz_grade'))
    runner = unittest.TextTestRunner()
    print(runner.run(suite))
                      
my_suite()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 3
#       1 import unittest
#       2 from canvasacademicinsights.tests.test_canvasinsights import TestMain
# ----> 3 from canvasacademicinsights.tests.test_canvasdataretriever import TestCleaner
#       5 def my_suite():
#       6     suite = unittest.TestSuite()
#
# ImportError: cannot import name 'TestCleaner' from 'canvasacademicinsights.tests.test_canvasdataretriever' (C:\Users\yueya\OneDrive\School\MDS\MDS repo 2\533Step2\canvasacademicinsights\tests\test_canvasdataretriever.py)
